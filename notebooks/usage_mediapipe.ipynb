# %%
import os, sys
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from PIL import Image

# %% [markdown]
# # MCG-NJU/videomae-base-finetuned-kinetics

# %%
from src.utils import hand_extraction

# %%
data = hand_extraction(
        image_path=r'..\data\development\2025.png',
        is_extract_arm=False,
        save_path=r'..\data\development\hand_data',
        is_return_picture=True
)
# Out:
# ✅ Đã lưu dữ liệu 2 tay vào chung file: ..\data\development\hand_data

# %%
data[0]
# Out:
# {'left': array([[ 3.7144452e-01,  6.3078350e-01, -1.9994641e-07],
#         [ 4.2378154e-01,  6.1182737e-01,  6.6398960e-03],
#         [ 4.5638028e-01,  5.8087832e-01,  6.2278118e-03],
#         [ 4.8431009e-01,  5.6059742e-01,  7.5247081e-04],
#         [ 5.0891453e-01,  5.4267687e-01, -3.8885251e-03],
#         [ 4.4794261e-01,  5.4753220e-01,  8.8911280e-03],
#         [ 4.8045975e-01,  5.4781073e-01, -1.0715192e-02],
#         [ 4.8875347e-01,  5.7550138e-01, -2.3626016e-02],
#         [ 4.9229577e-01,  5.9894913e-01, -2.8434677e-02],
#         [ 4.3353072e-01,  5.4907602e-01, -3.7137375e-03],
#         [ 4.7309884e-01,  5.5313128e-01, -2.7675776e-02],
#         [ 4.8203942e-01,  5.8394837e-01, -4.0063769e-02],
#         [ 4.8431867e-01,  6.0782498e-01, -4.3395340e-02],
#         [ 4.1848502e-01,  5.5331385e-01, -1.8254783e-02],
#         [ 4.5836961e-01,  5.5654162e-01, -4.0487591e-02],
#         [ 4.7042468e-01,  5.8443302e-01, -4.6867047e-02],
#         [ 4.7431716e-01,  6.0463929e-01, -4.5329325e-02],
#         [ 4.0344283e-01,  5.6059253e-01, -3.2148208e-02],
#         [ 4.2080542e-01,  5.3515941e-01, -4.3411717e-02],
#         [ 4.3361637e-01,  5.1884609e-01, -4.6693824e-02],
#         [ 4.4660181e-01,  5.0528842e-01, -4.7131170e-02]], dtype=float32),
#  'right': array([[ 6.4560920e-01,  6.6881484e-01, -3.1336086e-07],
#         [ 6.3200504e-01,  6.2761492e-01,  5.5585708e-03],
#         [ 6.1569268e-01,  5.8416915e-01,  2.8096305e-03],
#         [ 6.0516113e-01,  5.5410635e-01, -2.1661785e-03],
#         [ 6.0125923e-01,  5.3161639e-01, -6.0723191e-03],
#         [ 6.3314456e-01,  5.5564082e-01, -1.4009755e-02],
#         [ 5.7096553e-01,  5.5700356e-01, -2.8692532e-02],
#         [ 5.7775342e-01,  5.7864755e-01, -3.2758188e-02],
#         [ 5.9570247e-01,  5.8271652e-01, -3.3887796e-02],
#         [ 6.3566762e-01,  5.7491392e-01, -2.3929456e-02],
#         [ 5.6556499e-01,  5.7734537e-01, -3.7677996e-02],
#         [ 5.7604295e-01,  5.9703153e-01, -3.3157054e-02],
#         [ 5.9329110e-01,  6.0040873e-01, -2.9628482e-02],
#         [ 6.3182765e-01,  5.9957743e-01, -3.4004264e-02],
#         [ 5.6515038e-01,  5.9485358e-01, -4.7291256e-02],
#         [ 5.7493860e-01,  6.1308515e-01, -3.6460109e-02],
#         [ 5.9407562e-01,  6.2064505e-01, -2.7952120e-02],
#         [ 6.2495261e-01,  6.2683451e-01, -4.3567196e-02],
#         [ 5.7990015e-01,  6.0632628e-01, -5.7273120e-02],
#         [ 5.7384115e-01,  5.9992623e-01, -5.6405768e-02],
#         [ 5.7907593e-01,  5.9369844e-01, -5.3489152e-02]], dtype=float32)}

# %%
Image.fromarray(data[1])#
# Out:
# <PIL.Image.Image image mode=RGB size=643x672>
